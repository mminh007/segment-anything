# %%
from PIL import Image

# %%
im = "./demo_webui/images/seg (2).png"
image = Image.open(im)

# %%
type(image)
# Out:
# PIL.Image.Image

# %%
import numpy as np
im = np.array(image)
im.shape
# Out:
# (2048, 2048, 3)

# %%
imgz = Image.fromarray(im)
type(imgz)
# Out:
# PIL.Image.Image

# %%
imgz.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 imgz.shape
#
# AttributeError: 'Image' object has no attribute 'shape'
